# %% [markdown]
# # 과제1. car seat 매출 분석

# %% [markdown]
# * 카시트에 대해서 지역 매장 별 매출액을 살펴보고자 합니다.
# * 행은 자사 매장이 있는 각 지역별 데이터 입니다.

# %% [markdown]
# ![](https://cdn.images.express.co.uk/img/dynamic/24/590x/child-car-seat-986556.jpg?r=1532946857754)

# %% [markdown]
# ## 0.환경설정
#
# * 필요한 라이브러리 로딩, 데이터셋 가져오기

# %% [markdown]
# ### 1) 라이브러리 로딩

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 2) 데이터 불러오기

# %%
path = 'https://raw.githubusercontent.com/JunhoYu/Data-Analysis/main/Carseats.csv'
data = pd.read_csv(path)
data.head(10)
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0   9.50        138      73           11         276    120       Bad   42
# 1  11.22        111      48           16         260     83      Good   65
# 2  10.06        113      35           10         269     80    Medium   59
# 3   7.40        117     100            4         466     97    Medium   55
# 4   4.15        141      64            3         340    128       Bad   38
# 5  10.81        124     113           13         501     72       Bad   78
# 6   6.63        115     105            0          45    108    Medium   71
# 7  11.85        136      81           15         425    120      Good   67
# 8   6.54        132     110            0         108    124    Medium   76
# 9   4.69        132     113            0         131    124    Medium   76
#
#    Education Urban   US
# 0         17   Yes  Yes
# 1         10   Yes  Yes
# 2         12   Yes  Yes
# 3         14   Yes  Yes
# ...

# %% [markdown]
# |	변수명	|	설명	|	구분	|
# |	----	|	----	|	----	|
# |	Sales 	|	 각 지역 판매량(단위 : 1000개)	|	Target	|
# |	CompPrice 	|	 각 지역 경쟁사 가격(단위 : 달러)	|	feature	|
# |	Income 	|	 각 지역 소득수준(단위 : 천달러)	|	feature	|
# |	Advertising 	|	 각 지역, 회사의 광고 예산(단위 : 1000달러)	|	feature	|
# |	Population 	|	 지역 인구수(단위 : 1000명)	|	feature	|
# |	Price 	|	 자사 지역별 판매가격(달러)	|	feature	|
# |	Education 	|	 교육수준(10~18), 범주	|	feature	|
# |	ShelveLoc 	|	 진열상태(Good, Medium, Bad)	|	feature	|
# |	Age 	|	 지역 인구의 평균 연령	|	feature	|
# |	US 	|	 매장이 미국에 있는지 여부(Yes, No)	|	feature	|
# |	Urban 	|	 매장이 도심에 있는지 여부(Yes, No)	|	feature	|

# %% [markdown]
# ## 1.데이터 살펴보기

# %% [markdown]
# * 주어진 데이터로부터 다양한 조회 방법을 통해 비즈니스 사항을 파악해 봅시다.
# * 데이터와 비즈니스를 파악하기 위한 질문을 10개 이상 도출하고, 조회해 봅시다.

# %%
data.tail(10)
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 390   5.47        108      75            9          61    111    Medium   67
# 391   6.10        153      63            0          49    124       Bad   56
# 392   4.53        129      42           13         315    130       Bad   34
# 393   5.57        109      51           10          26    120    Medium   30
# 394   5.35        130      58           19         366    139       Bad   33
# 395  12.57        138     108           17         203    128      Good   33
# 396   6.14        139      23            3          37    120    Medium   55
# 397   7.41        162      26           12         368    159    Medium   40
# 398   5.94        100      79            7         284     95       Bad   50
# 399   9.71        134      37            0          27    120      Good   49
#
#      Education Urban   US
# 390         12   Yes  Yes
# 391         16   Yes   No
# 392         13   Yes  Yes
# ...

# %%
print("행렬 갯수")
print(data.shape)
# Out:
# 행렬 갯수
# (400, 11)

# %%
print(data.columns)
print(data.columns[1])
print("열확인")
print("-"*50)
print(data.columns.values)
print(data.columns.values[0])
print(data.columns.values[1])
if data.columns.values[0]==data.columns[0]:
    print("values 안써도 된다 형태만 array 그냥 리스트 형인가 어레이 형인가의 차이")
print("열 확인 data.columns.values")
# Out:
# Index(['Sales', 'CompPrice', 'Income', 'Advertising', 'Population', 'Price',
#        'ShelveLoc', 'Age', 'Education', 'Urban', 'US'],
#       dtype='object')
# CompPrice
# 열확인
# --------------------------------------------------
# ['Sales' 'CompPrice' 'Income' 'Advertising' 'Population' 'Price'
#  'ShelveLoc' 'Age' 'Education' 'Urban' 'US']
# Sales
# CompPrice
# values 안써도 된다 형태만 array 그냥 리스트 형인가 어레이 형인가의 차이
# 열 확인 data.columns.values

# %%
print(list(data))
print("리스트 형태")
print("열 이름을 리스트 형태로 아까꺼랑은 다름 ")
print("list(data)는 열이름을 리스트로 반환")
# Out:
# ['Sales', 'CompPrice', 'Income', 'Advertising', 'Population', 'Price', 'ShelveLoc', 'Age', 'Education', 'Urban', 'US']
# 리스트 형태
# 열 이름을 리스트 형태로 아까꺼랑은 다름
# list(data)는 열이름을 리스트로 반환

# %%
'''
int64: 정수형 데이터(int)
float64: 실수형 데이터(float)
object: 문자열 데이터(string)
'''
print(data.dtypes)
# Out:
# Sales          float64
# CompPrice        int64
# Income           int64
# Advertising      int64
# Population       int64
# Price            int64
# ShelveLoc       object
# Age              int64
# Education        int64
# Urban           object
# US              object
# dtype: object

# %%
# 열 자료형, 값 개수 확인
print(data.info())
#1196행 11열 전부 보여줌
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sales        400 non-null    float64
#  1   CompPrice    400 non-null    int64
#  2   Income       400 non-null    int64
#  3   Advertising  400 non-null    int64
#  4   Population   400 non-null    int64
#  5   Price        400 non-null    int64
#  6   ShelveLoc    400 non-null    object
#  7   Age          400 non-null    int64
#  8   Education    400 non-null    int64
#  9   Urban        400 non-null    object
#  10  US           400 non-null    object
# dtypes: float64(1), int64(7), object(3)
# memory usage: 34.5+ KB
# None

# %%
print(data.describe())
# Out:
#             Sales   CompPrice      Income  Advertising  Population  \
# count  400.000000  400.000000  400.000000   400.000000  400.000000
# mean     7.496325  124.975000   68.657500     6.635000  264.840000
# std      2.824115   15.334512   27.986037     6.650364  147.376436
# min      0.000000   77.000000   21.000000     0.000000   10.000000
# 25%      5.390000  115.000000   42.750000     0.000000  139.000000
# 50%      7.490000  125.000000   69.000000     5.000000  272.000000
# 75%      9.320000  135.000000   91.000000    12.000000  398.500000
# max     16.270000  175.000000  120.000000    29.000000  509.000000
#
#             Price         Age   Education
# count  400.000000  400.000000  400.000000
# mean   115.795000   53.322500   13.900000
# std     23.676664   16.200297    2.620528
# min     24.000000   25.000000   10.000000
# 25%    100.000000   39.750000   12.000000
# 50%    117.000000   54.500000   14.000000
# 75%    131.000000   66.000000   16.000000
# ...

# %%
print(data[['Sales','CompPrice']].describe())
# Out:
#             Sales   CompPrice
# count  400.000000  400.000000
# mean     7.496325  124.975000
# std      2.824115   15.334512
# min      0.000000   77.000000
# 25%      5.390000  115.000000
# 50%      7.490000  125.000000
# 75%      9.320000  135.000000
# max     16.270000  175.000000

# %%
print(data['Sales'].describe())
# Out:
# count    400.000000
# mean       7.496325
# std        2.824115
# min        0.000000
# 25%        5.390000
# 50%        7.490000
# 75%        9.320000
# max       16.270000
# Name: Sales, dtype: float64

# %%
print(data.sort_values(by='Age',ascending=False))
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 257   8.67        125      62           14         477    112    Medium   80
# 91    4.81         97      46           11         267    107    Medium   80
# 137   6.52        128      42            0         436    118    Medium   80
# 255   7.71        123      81            8         198     81       Bad   80
# 221   6.43        124      44            0         125    107    Medium   80
# ..     ...        ...     ...          ...         ...    ...       ...  ...
# 218   9.70        138      61           12         156    120    Medium   25
# 182   4.74        137      60            4         230    140       Bad   25
# 175   7.54        115      89            0          38    122    Medium   25
# 178  10.66        104      71           14          89     81    Medium   25
# 153   5.93        150      36            7         488    150    Medium   25
#
#      Education Urban   US
# ...

# %%
print(data.sort_values(by='Age',ascending=True))
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 363  10.26        111      75            1         377    108      Good   25
# 263   7.77        116      26            6         434    115    Medium   25
# 203   2.05        131      82            0         132    157       Bad   25
# 178  10.66        104      71           14          89     81    Medium   25
# 218   9.70        138      61           12         156    120    Medium   25
# ..     ...        ...     ...          ...         ...    ...       ...  ...
# 116   5.08        135      75            0         202    128    Medium   80
# 183   5.32        118      74            6         426    102    Medium   80
# 137   6.52        128      42            0         436    118    Medium   80
# 50    1.42         99      32           18         341    108       Bad   80
# 257   8.67        125      62           14         477    112    Medium   80
#
#      Education Urban   US
# ...

# %%
data.sort_values(by=['Price','Advertising','Age','Education'],ascending=[True,True,True,True]).head(50)
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 42   10.43         77      69            0          25     24    Medium   50
# 125   9.34         89      78            0         181     49    Medium   43
# 367  14.37         95     106            0         256     53      Good   52
# 313   9.33        103      81            3         491     54    Medium   66
# 171  12.49         93     106           12         416     55    Medium   75
# 272  12.98        113      33            0          14     63      Good   38
# 208   7.78         86      54            0         497     64       Bad   33
# 18   13.91        110     110            0         408     68      Good   46
# 383   9.35         98     117            0          76     68    Medium   63
# 155   7.71         98      72            0          59     69    Medium   65
# 159   9.32        119      60            0         372     70       Bad   30
# ...

# %%
data.sort_values(by=['Advertising','Price','Age','Education'],ascending=[True,True,True,True]).head(50)
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 42   10.43         77      69            0          25     24    Medium   50
# 125   9.34         89      78            0         181     49    Medium   43
# 367  14.37         95     106            0         256     53      Good   52
# 272  12.98        113      33            0          14     63      Good   38
# 208   7.78         86      54            0         497     64       Bad   33
# 18   13.91        110     110            0         408     68      Good   46
# 383   9.35         98     117            0          76     68    Medium   63
# 155   7.71         98      72            0          59     69    Medium   65
# 159   9.32        119      60            0         372     70       Bad   30
# 229  11.19         98     104            0         404     72    Medium   27
# 258   3.47        108      38            0         251     81       Bad   72
# ...

# %%
data.sort_values(by=['Education','Price','Advertising','Age'],ascending=[True,True,True,True]).head(50)
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 383   9.35         98     117            0          76     68    Medium   63
# 316  15.63        122      36            5         369     72      Good   35
# 1    11.22        111      48           16         260     83      Good   65
# 121  11.67        125      89           10         380     87       Bad   28
# 245  10.00        114      43            0         199     88      Good   57
# 270  11.99        119      26            0         284     89      Good   26
# 293  11.28        123      84            0          74     89      Good   59
# 341   7.38         98     120            0         268     93    Medium   72
# 193  13.28        139      70            7          71     96      Good   61
# 207   8.19        111     105            0         466     97       Bad   61
# 10    9.01        121      78            9         150    100       Bad   26
# ...

# %%
data.sort_values(by=['Education','Price','Advertising','Age'],ascending=[True,True,True,True]).reset_index().head(50)
#복합 정렬 배치 교육 가격 광고 나이 순 저거 순서 바꾸면 바뀜
# Out:
#     index  Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  \
# 0     383   9.35         98     117            0          76     68    Medium
# 1     316  15.63        122      36            5         369     72      Good
# 2       1  11.22        111      48           16         260     83      Good
# 3     121  11.67        125      89           10         380     87       Bad
# 4     245  10.00        114      43            0         199     88      Good
# 5     270  11.99        119      26            0         284     89      Good
# 6     293  11.28        123      84            0          74     89      Good
# 7     341   7.38         98     120            0         268     93    Medium
# 8     193  13.28        139      70            7          71     96      Good
# 9     207   8.19        111     105            0         466     97       Bad
# 10     10   9.01        121      78            9         150    100       Bad
# ...

# %%
data.sort_values(by=['Education','Price','Advertising','Age'],ascending=[True,True,True,True]).reset_index(drop=False).head(10)
# Out:
#    index  Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  \
# 0    383   9.35         98     117            0          76     68    Medium
# 1    316  15.63        122      36            5         369     72      Good
# 2      1  11.22        111      48           16         260     83      Good
# 3    121  11.67        125      89           10         380     87       Bad
# 4    245  10.00        114      43            0         199     88      Good
# 5    270  11.99        119      26            0         284     89      Good
# 6    293  11.28        123      84            0          74     89      Good
# 7    341   7.38         98     120            0         268     93    Medium
# 8    193  13.28        139      70            7          71     96      Good
# 9    207   8.19        111     105            0         466     97       Bad
#
#    Age  Education Urban   US
# 0   63         10   Yes   No
# 1   35         10   Yes  Yes
# 2   65         10   Yes  Yes
# ...

# %%
data.sort_values(by=['Education','Price','Advertising','Age'],ascending=[True,True,True,True]).reset_index(drop=True).head(10)
#이거 의미 없음
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0   9.35         98     117            0          76     68    Medium   63
# 1  15.63        122      36            5         369     72      Good   35
# 2  11.22        111      48           16         260     83      Good   65
# 3  11.67        125      89           10         380     87       Bad   28
# 4  10.00        114      43            0         199     88      Good   57
# 5  11.99        119      26            0         284     89      Good   26
# 6  11.28        123      84            0          74     89      Good   59
# 7   7.38         98     120            0         268     93    Medium   72
# 8  13.28        139      70            7          71     96      Good   61
# 9   8.19        111     105            0         466     97       Bad   61
#
#    Education Urban   US
# 0         10   Yes   No
# 1         10   Yes  Yes
# 2         10   Yes  Yes
# 3         10   Yes  Yes
# ...

# %%
print(data.head(5))
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0   9.50        138      73           11         276    120       Bad   42
# 1  11.22        111      48           16         260     83      Good   65
# 2  10.06        113      35           10         269     80    Medium   59
# 3   7.40        117     100            4         466     97    Medium   55
# 4   4.15        141      64            3         340    128       Bad   38
#
#    Education Urban   US
# 0         17   Yes  Yes
# 1         10   Yes  Yes
# 2         12   Yes  Yes
# 3         14   Yes  Yes
# 4         13   Yes   No

# %%
print(data['Sales'])
# Out:
# 0       9.50
# 1      11.22
# 2      10.06
# 3       7.40
# 4       4.15
#        ...
# 395    12.57
# 396     6.14
# 397     7.41
# 398     5.94
# 399     9.71
# Name: Sales, Length: 400, dtype: float64

# %%
print(type(data['Age']))
#시리즈다
# Out:
# <class 'pandas.core.series.Series'>

# %%
print(data['Age'].unique())
# Out:
# [42 65 59 55 38 78 71 67 76 26 50 62 53 52 63 46 69 35 79 54 64 58 30 44
#  60 73 48 32 80 75 39 61 74 29 77 56 47 25 31 36 41 68 70 28 43 49 45 33
#  34 51 40 72 57 27 66 37]

# %%
print(data['Urban'].unique())
# Out:
# ['Yes' 'No']

# %%
print(data.columns)
# Out:
# Index(['Sales', 'CompPrice', 'Income', 'Advertising', 'Population', 'Price',
#        'ShelveLoc', 'Age', 'Education', 'Urban', 'US'],
#       dtype='object')

# %%
print(data['ShelveLoc'].unique())
# Out:
# ['Bad' 'Good' 'Medium']

# %%
print(data['ShelveLoc'].value_counts())
# Out:
# Medium    219
# Bad        96
# Good       85
# Name: ShelveLoc, dtype: int64

# %%
print(data[['ShelveLoc','Income']].value_counts())
# Out:
# ShelveLoc  Income
# Medium     69        9
#            73        5
#            26        5
#            84        5
#            100       5
#                     ..
# Good       36        1
#            38        1
# Medium     23        1
# Good       39        1
# Bad        21        1
# Length: 212, dtype: int64

# %%
print(data.head(10))
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0   9.50        138      73           11         276    120       Bad   42
# 1  11.22        111      48           16         260     83      Good   65
# 2  10.06        113      35           10         269     80    Medium   59
# 3   7.40        117     100            4         466     97    Medium   55
# 4   4.15        141      64            3         340    128       Bad   38
# 5  10.81        124     113           13         501     72       Bad   78
# 6   6.63        115     105            0          45    108    Medium   71
# 7  11.85        136      81           15         425    120      Good   67
# 8   6.54        132     110            0         108    124    Medium   76
# 9   4.69        132     113            0         131    124    Medium   76
#
#    Education Urban   US
# 0         17   Yes  Yes
# 1         10   Yes  Yes
# 2         12   Yes  Yes
# 3         14   Yes  Yes
# ...

# %%
print(data['CompPrice'].sum())
# Out:
# 49990

# %%
print(data['ShelveLoc'].sum())
# Out:
# ...

# %%
print(data['CompPrice'].max())
# Out:
# 175

# %%
print(data['CompPrice'].min())
# Out:
# 77

# %%
print(data['ShelveLoc'].max())
# Out:
# Medium

# %%
print(data['ShelveLoc'].min())
# Out:
# Bad

# %%
print(data[['CompPrice','Age']].min())
# Out:
# CompPrice    77
# Age          25
# dtype: int64

# %%
print(data[['CompPrice','Age']].mean())
# Out:
# CompPrice    124.9750
# Age           53.3225
# dtype: float64

# %%
print(data[['CompPrice','Age']].median())
# Out:
# CompPrice    125.0
# Age           54.5
# dtype: float64

# %%
data.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0   9.50        138      73           11         276    120       Bad   42
# 1  11.22        111      48           16         260     83      Good   65
# 2  10.06        113      35           10         269     80    Medium   59
# 3   7.40        117     100            4         466     97    Medium   55
# 4   4.15        141      64            3         340    128       Bad   38
#
#    Education Urban   US
# 0         17   Yes  Yes
# 1         10   Yes  Yes
# 2         12   Yes  Yes
# 3         14   Yes  Yes
# 4         13   Yes   No

# %%
data.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0   9.50        138      73           11         276    120       Bad   42
# 1  11.22        111      48           16         260     83      Good   65
# 2  10.06        113      35           10         269     80    Medium   59
# 3   7.40        117     100            4         466     97    Medium   55
# 4   4.15        141      64            3         340    128       Bad   38
#
#    Education Urban   US
# 0         17   Yes  Yes
# 1         10   Yes  Yes
# 2         12   Yes  Yes
# 3         14   Yes  Yes
# 4         13   Yes   No

# %%
data['Sales']
# Out:
# 0       9.50
# 1      11.22
# 2      10.06
# 3       7.40
# 4       4.15
#        ...
# 395    12.57
# 396     6.14
# 397     7.41
# 398     5.94
# 399     9.71
# Name: Sales, Length: 400, dtype: float64

# %%
data[['Sales','CompPrice']]
# Out:
#      Sales  CompPrice
# 0     9.50        138
# 1    11.22        111
# 2    10.06        113
# 3     7.40        117
# 4     4.15        141
# ..     ...        ...
# 395  12.57        138
# 396   6.14        139
# 397   7.41        162
# 398   5.94        100
# 399   9.71        134
#
# [400 rows x 2 columns]

# %%
data.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0   9.50        138      73           11         276    120       Bad   42
# 1  11.22        111      48           16         260     83      Good   65
# 2  10.06        113      35           10         269     80    Medium   59
# 3   7.40        117     100            4         466     97    Medium   55
# 4   4.15        141      64            3         340    128       Bad   38
#
#    Education Urban   US
# 0         17   Yes  Yes
# 1         10   Yes  Yes
# 2         12   Yes  Yes
# 3         14   Yes  Yes
# 4         13   Yes   No

# %%
data.sort_values(by='Sales',axis=0,ascending=False)
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 376  16.27        141      60           19         319     92      Good   44
# 316  15.63        122      36            5         369     72      Good   35
# 25   14.90        139      32            0         176     82      Good   54
# 367  14.37         95     106            0         256     53      Good   52
# 18   13.91        110     110            0         408     68      Good   46
# ..     ...        ...     ...          ...         ...    ...       ...  ...
# 57    0.91         93      91            0          22    117       Bad   75
# 143   0.53        122      88            7          36    159       Bad   28
# 165   0.37        147      58            7         100    191       Bad   27
# 106   0.16        102      33            0         217    139    Medium   70
# 174   0.00        139      24            0         358    185    Medium   79
#
#      Education Urban   US
# ...

# %%
data.sort_values(by='Price',ascending=False).head(10)
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 165   0.37        147      58            7         100    191       Bad   27
# 174   0.00        139      24            0         358    185    Medium   79
# 191   6.67        156      42           13         170    173      Good   74
# 315   6.39        131      21            8         220    171      Good   29
# 269   5.01        159      69            0         438    166    Medium   46
# 310   9.53        175      65           29         419    166    Medium   53
# 356   3.58        142     109            0         111    164      Good   72
# 228   5.40        149      73           13         381    163       Bad   26
# 365   6.53        154      30            0         122    162    Medium   57
# 206   4.97        162      67            0          27    160    Medium   77
#
#      Education Urban   US
# 165         15   Yes  Yes
# 174         15    No   No
# 191         14   Yes  Yes
# ...

# %%
#data[['Age','Income']].sort_values(by='CompPrice',ascending=False)
#오류

# %%
data.columns
# Out:
# Index(['Sales', 'CompPrice', 'Income', 'Advertising', 'Population', 'Price',
#        'ShelveLoc', 'Age', 'Education', 'Urban', 'US'],
#       dtype='object')

# %%
data.head(10)
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0   9.50        138      73           11         276    120       Bad   42
# 1  11.22        111      48           16         260     83      Good   65
# 2  10.06        113      35           10         269     80    Medium   59
# 3   7.40        117     100            4         466     97    Medium   55
# 4   4.15        141      64            3         340    128       Bad   38
# 5  10.81        124     113           13         501     72       Bad   78
# 6   6.63        115     105            0          45    108    Medium   71
# 7  11.85        136      81           15         425    120      Good   67
# 8   6.54        132     110            0         108    124    Medium   76
# 9   4.69        132     113            0         131    124    Medium   76
#
#    Education Urban   US
# 0         17   Yes  Yes
# 1         10   Yes  Yes
# 2         12   Yes  Yes
# 3         14   Yes  Yes
# ...

# %%
data['Sales'].head(10)>10
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# 4    False
# 5     True
# 6    False
# 7     True
# 8    False
# 9    False
# Name: Sales, dtype: bool

# %%
data.loc[data['Sales']>10].head(20)
# Out:
#     Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 1   11.22        111      48           16         260     83      Good   65
# 2   10.06        113      35           10         269     80    Medium   59
# 5   10.81        124     113           13         501     72       Bad   78
# 7   11.85        136      81           15         425    120      Good   67
# 11  11.96        117      94            4         503     94      Good   50
# 13  10.96        115      28           11          29     86      Good   53
# 14  11.17        107     117           11         148    118      Good   52
# 17  12.29        147      74           13         251    131      Good   52
# 18  13.91        110     110            0         408     68      Good   46
# 21  12.13        134      29           12         239    109      Good   62
# 24  10.14        145     119           16         294    113       Bad   42
# ...

# %%
data.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0   9.50        138      73           11         276    120       Bad   42
# 1  11.22        111      48           16         260     83      Good   65
# 2  10.06        113      35           10         269     80    Medium   59
# 3   7.40        117     100            4         466     97    Medium   55
# 4   4.15        141      64            3         340    128       Bad   38
#
#    Education Urban   US
# 0         17   Yes  Yes
# 1         10   Yes  Yes
# 2         12   Yes  Yes
# 3         14   Yes  Yes
# 4         13   Yes   No

# %%
data.loc[(data['Sales']>10)&(data['Income']>50)].head(10)
# Out:
#     Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 5   10.81        124     113           13         501     72       Bad   78
# 7   11.85        136      81           15         425    120      Good   67
# 11  11.96        117      94            4         503     94      Good   50
# 14  11.17        107     117           11         148    118      Good   52
# 17  12.29        147      74           13         251    131      Good   52
# 18  13.91        110     110            0         408     68      Good   46
# 24  10.14        145     119           16         294    113       Bad   42
# 30  13.55        125      94            0         447     89      Good   30
# 35  11.07        131      84           11          29     96    Medium   44
# 42  10.43         77      69            0          25     24    Medium   50
#
#     Education Urban   US
# 5          16    No  Yes
# 7          10   Yes  Yes
# 11         13   Yes  Yes
# 14         18   Yes  Yes
# ...

# %%
data.loc[(data['Sales']>10)|(data['Income']>50)].head(10)
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0   9.50        138      73           11         276    120       Bad   42
# 1  11.22        111      48           16         260     83      Good   65
# 2  10.06        113      35           10         269     80    Medium   59
# 3   7.40        117     100            4         466     97    Medium   55
# 4   4.15        141      64            3         340    128       Bad   38
# 5  10.81        124     113           13         501     72       Bad   78
# 6   6.63        115     105            0          45    108    Medium   71
# 7  11.85        136      81           15         425    120      Good   67
# 8   6.54        132     110            0         108    124    Medium   76
# 9   4.69        132     113            0         131    124    Medium   76
#
#    Education Urban   US
# 0         17   Yes  Yes
# 1         10   Yes  Yes
# 2         12   Yes  Yes
# 3         14   Yes  Yes
# ...

# %%
data
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120       Bad   42
# 1    11.22        111      48           16         260     83      Good   65
# 2    10.06        113      35           10         269     80    Medium   59
# 3     7.40        117     100            4         466     97    Medium   55
# 4     4.15        141      64            3         340    128       Bad   38
# ..     ...        ...     ...          ...         ...    ...       ...  ...
# 395  12.57        138     108           17         203    128      Good   33
# 396   6.14        139      23            3          37    120    Medium   55
# 397   7.41        162      26           12         368    159    Medium   40
# 398   5.94        100      79            7         284     95       Bad   50
# 399   9.71        134      37            0          27    120      Good   49
#
#      Education Urban   US
# ...

# %%
data.loc[data['Education'].isin([11,12])]
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 2    10.06        113      35           10         269     80    Medium   59
# 19    8.73        129      76           16          58    121    Medium   69
# 24   10.14        145     119           16         294    113       Bad   42
# 25   14.90        139      32            0         176     82      Good   54
# 26    8.33        107     115           11         496    131      Good   50
# ..     ...        ...     ...          ...         ...    ...       ...  ...
# 384  12.85        123      37           15         348    112      Good   28
# 389   8.44        128      42            8         328    107    Medium   35
# 390   5.47        108      75            9          61    111    Medium   67
# 396   6.14        139      23            3          37    120    Medium   55
# 398   5.94        100      79            7         284     95       Bad   50
#
#      Education Urban   US
# ...

# %%
data
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120       Bad   42
# 1    11.22        111      48           16         260     83      Good   65
# 2    10.06        113      35           10         269     80    Medium   59
# 3     7.40        117     100            4         466     97    Medium   55
# 4     4.15        141      64            3         340    128       Bad   38
# ..     ...        ...     ...          ...         ...    ...       ...  ...
# 395  12.57        138     108           17         203    128      Good   33
# 396   6.14        139      23            3          37    120    Medium   55
# 397   7.41        162      26           12         368    159    Medium   40
# 398   5.94        100      79            7         284     95       Bad   50
# 399   9.71        134      37            0          27    120      Good   49
#
#      Education Urban   US
# ...

# %%
data.loc[(data['Education']).between(12,15,inclusive='neither')]
#Series.between(left, right, inclusive='both') or left True Series.between(left, right, inclusive='both')
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 3     7.40        117     100            4         466     97    Medium   55
# 4     4.15        141      64            3         340    128       Bad   38
# 11   11.96        117      94            4         503     94      Good   50
# 16    7.58        118      32            0         284    110      Good   63
# 22    5.08        128      46            6         497    138    Medium   42
# ..     ...        ...     ...          ...         ...    ...       ...  ...
# 381   3.90        124      65           21         496    151       Bad   77
# 382   4.95        121      28           19         315    121    Medium   66
# 387   8.67        142      73           14         238    115    Medium   73
# 392   4.53        129      42           13         315    130       Bad   34
# 395  12.57        138     108           17         203    128      Good   33
#
#      Education Urban   US
# ...

# %%
data.loc[(data['Education']).between(11,15)]
#Series.between(left, right, inclusive='both')
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 2    10.06        113      35           10         269     80    Medium   59
# 3     7.40        117     100            4         466     97    Medium   55
# 4     4.15        141      64            3         340    128       Bad   38
# 6     6.63        115     105            0          45    108    Medium   71
# 11   11.96        117      94            4         503     94      Good   50
# ..     ...        ...     ...          ...         ...    ...       ...  ...
# 390   5.47        108      75            9          61    111    Medium   67
# 392   4.53        129      42           13         315    130       Bad   34
# 395  12.57        138     108           17         203    128      Good   33
# 396   6.14        139      23            3          37    120    Medium   55
# 398   5.94        100      79            7         284     95       Bad   50
#
#      Education Urban   US
# ...

# %%
data.loc[data['Education']>=12,['Age','Sales','CompPrice']]
# Out:
#      Age  Sales  CompPrice
# 0     42   9.50        138
# 2     59  10.06        113
# 3     55   7.40        117
# 4     38   4.15        141
# 5     78  10.81        124
# ..   ...    ...        ...
# 394   33   5.35        130
# 395   33  12.57        138
# 397   40   7.41        162
# 398   50   5.94        100
# 399   49   9.71        134
#
# [304 rows x 3 columns]

# %%
data.loc[data['Education']>12,['Age']]
# Out:
#      Age
# 0     42
# 3     55
# 4     38
# 5     78
# 6     71
# ..   ...
# 393   30
# 394   33
# 395   33
# 397   40
# 399   49
#
# [255 rows x 1 columns]

# %%
data.iloc[0:9]
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0   9.50        138      73           11         276    120       Bad   42
# 1  11.22        111      48           16         260     83      Good   65
# 2  10.06        113      35           10         269     80    Medium   59
# 3   7.40        117     100            4         466     97    Medium   55
# 4   4.15        141      64            3         340    128       Bad   38
# 5  10.81        124     113           13         501     72       Bad   78
# 6   6.63        115     105            0          45    108    Medium   71
# 7  11.85        136      81           15         425    120      Good   67
# 8   6.54        132     110            0         108    124    Medium   76
#
#    Education Urban   US
# 0         17   Yes  Yes
# 1         10   Yes  Yes
# 2         12   Yes  Yes
# 3         14   Yes  Yes
# 4         13   Yes   No
# 5         16    No  Yes
# 6         15   Yes   No
# ...

# %%
data.head(10)
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0   9.50        138      73           11         276    120       Bad   42
# 1  11.22        111      48           16         260     83      Good   65
# 2  10.06        113      35           10         269     80    Medium   59
# 3   7.40        117     100            4         466     97    Medium   55
# 4   4.15        141      64            3         340    128       Bad   38
# 5  10.81        124     113           13         501     72       Bad   78
# 6   6.63        115     105            0          45    108    Medium   71
# 7  11.85        136      81           15         425    120      Good   67
# 8   6.54        132     110            0         108    124    Medium   76
# 9   4.69        132     113            0         131    124    Medium   76
#
#    Education Urban   US
# 0         17   Yes  Yes
# 1         10   Yes  Yes
# 2         12   Yes  Yes
# 3         14   Yes  Yes
# ...

# %%
data.loc[0:9,['Sales','CompPrice']]
# Out:
#    Sales  CompPrice
# 0   9.50        138
# 1  11.22        111
# 2  10.06        113
# 3   7.40        117
# 4   4.15        141
# 5  10.81        124
# 6   6.63        115
# 7  11.85        136
# 8   6.54        132
# 9   4.69        132

# %%
data[['Sales','CompPrice','Income']].sum()#mean median std
# Out:
# Sales         2998.53
# CompPrice    49990.00
# Income       27463.00
# dtype: float64

# %%
data.groupby(by='Sales',as_index=True)['CompPrice'].mean().head()
# Out:
# Sales
# 0.00    139.0
# 0.16    102.0
# 0.37    147.0
# 0.53    122.0
# 0.91     93.0
# Name: CompPrice, dtype: float64

# %%
data.groupby(by='Age',as_index=False)['Education'].mean().head()
# Out:
#    Age  Education
# 0   25  14.222222
# 1   26  13.625000
# 2   27  14.666667
# 3   28  14.428571
# 4   29  12.857143

# %%
data.groupby(by='Age',as_index=True)['Education'].mean().head()
# Out:
# Age
# 25    14.222222
# 26    13.625000
# 27    14.666667
# 28    14.428571
# 29    12.857143
# Name: Education, dtype: float64

# %%
data.groupby(by='Sales',as_index=False)[['Education','Age']].mean()
# Out:
#      Sales  Education   Age
# 0     0.00       15.0  79.0
# 1     0.16       18.0  70.0
# 2     0.37       15.0  27.0
# 3     0.53       17.0  28.0
# 4     0.91       11.0  75.0
# ..     ...        ...   ...
# 331  13.91       17.0  46.0
# 332  14.37       17.0  52.0
# 333  14.90       11.0  54.0
# 334  15.63       10.0  35.0
# 335  16.27       11.0  44.0
#
# [336 rows x 3 columns]

# %%
data.groupby(by='Sales',as_index=False)[['Education','Age']].sum()
# Out:
#      Sales  Education  Age
# 0     0.00         15   79
# 1     0.16         18   70
# 2     0.37         15   27
# 3     0.53         17   28
# 4     0.91         11   75
# ..     ...        ...  ...
# 331  13.91         17   46
# 332  14.37         17   52
# 333  14.90         11   54
# 334  15.63         10   35
# 335  16.27         11   44
#
# [336 rows x 3 columns]

# %%
data.groupby(by=['Sales','CompPrice'],as_index=False)[['Education','Age']].sum()
# Out:
#      Sales  CompPrice  Education  Age
# 0     0.00        139         15   79
# 1     0.16        102         18   70
# 2     0.37        147         15   27
# 3     0.53        122         17   28
# 4     0.91         93         11   75
# ..     ...        ...        ...  ...
# 394  13.91        110         17   46
# 395  14.37         95         17   52
# 396  14.90        139         11   54
# 397  15.63        122         10   35
# 398  16.27        141         11   44
#
# [399 rows x 4 columns]

# %%
a=data.groupby(by=['Sales','CompPrice'],as_index=False)[['Education','Age']].sum()

# %%
#a.sort_values(by='Population')#오류

# %%
data.groupby(by=['Sales','CompPrice'],as_index=False)[['Education','Age']].agg(['min','max','mean'])
# Out:
#                 Education           Age
#                       min max  mean min max  mean
# Sales CompPrice
# 0.00  139              15  15  15.0  79  79  79.0
# 0.16  102              18  18  18.0  70  70  70.0
# 0.37  147              15  15  15.0  27  27  27.0
# 0.53  122              17  17  17.0  28  28  28.0
# 0.91  93               11  11  11.0  75  75  75.0
# ...                   ...  ..   ...  ..  ..   ...
# 13.91 110              17  17  17.0  46  46  46.0
# 14.37 95               17  17  17.0  52  52  52.0
# 14.90 139              11  11  11.0  54  54  54.0
# 15.63 122              10  10  10.0  35  35  35.0
# 16.27 141              11  11  11.0  44  44  44.0
#
# [399 rows x 6 columns]

# %%
data.columns
# Out:
# Index(['Sales', 'CompPrice', 'Income', 'Advertising', 'Population', 'Price',
#        'ShelveLoc', 'Age', 'Education', 'Urban', 'US'],
#       dtype='object')

# %%
data.rename(columns={'Sales':'sale','CompPrice':'compprice','Advertising':'advertising','Price':'price','ShelveLoc':'shelveloc','Education':'education'},inplace=True)

# %%
#data.columns = [모두,모두해야됨]
#이건 쓰지말자

# %%
data.columns
# Out:
# Index(['sale', 'compprice', 'Income', 'advertising', 'Population', 'price',
#        'shelveloc', 'Age', 'education', 'Urban', 'US'],
#       dtype='object')

# %%
#열추가
data['real_price']=(1-data['sale']/100)*data['price']
data['real_price']=round(data['real_price'])

# %%
data.head()
# Out:
#     sale  compprice  Income  advertising  Population  price shelveloc  Age  \
# 0   9.50        138      73           11         276    120       Bad   42
# 1  11.22        111      48           16         260     83      Good   65
# 2  10.06        113      35           10         269     80    Medium   59
# 3   7.40        117     100            4         466     97    Medium   55
# 4   4.15        141      64            3         340    128       Bad   38
#
#    education Urban   US  real_price
# 0         17   Yes  Yes       109.0
# 1         10   Yes  Yes        74.0
# 2         12   Yes  Yes        72.0
# 3         14   Yes  Yes        90.0
# 4         13   Yes   No       123.0

# %%
data['그냥예시']=data['sale']

# %%
data.head()
# Out:
#     sale  compprice  Income  advertising  Population  price shelveloc  Age  \
# 0   9.50        138      73           11         276    120       Bad   42
# 1  11.22        111      48           16         260     83      Good   65
# 2  10.06        113      35           10         269     80    Medium   59
# 3   7.40        117     100            4         466     97    Medium   55
# 4   4.15        141      64            3         340    128       Bad   38
#
#    education Urban   US  real_price   그냥예시
# 0         17   Yes  Yes       109.0   9.50
# 1         10   Yes  Yes        74.0  11.22
# 2         12   Yes  Yes        72.0  10.06
# 3         14   Yes  Yes        90.0   7.40
# 4         13   Yes   No       123.0   4.15

# %%
data['aaa']=data['sale']

# %%
data.to_csv('data_practice',index='False')#임시저장

# %%
data.drop('그냥예시',axis=1,inplace=True)
data.head()
# Out:
#     sale  compprice  Income  advertising  Population  price shelveloc  Age  \
# 0   9.50        138      73           11         276    120       Bad   42
# 1  11.22        111      48           16         260     83      Good   65
# 2  10.06        113      35           10         269     80    Medium   59
# 3   7.40        117     100            4         466     97    Medium   55
# 4   4.15        141      64            3         340    128       Bad   38
#
#    education Urban   US  real_price    aaa
# 0         17   Yes  Yes       109.0   9.50
# 1         10   Yes  Yes        74.0  11.22
# 2         12   Yes  Yes        72.0  10.06
# 3         14   Yes  Yes        90.0   7.40
# 4         13   Yes   No       123.0   4.15

# %%
data.drop(['aaa','real_price'],axis=1,inplace=True)
data.head()
# Out:
#     sale  compprice  Income  advertising  Population  price shelveloc  Age  \
# 0   9.50        138      73           11         276    120       Bad   42
# 1  11.22        111      48           16         260     83      Good   65
# 2  10.06        113      35           10         269     80    Medium   59
# 3   7.40        117     100            4         466     97    Medium   55
# 4   4.15        141      64            3         340    128       Bad   38
#
#    education Urban   US
# 0         17   Yes  Yes
# 1         10   Yes  Yes
# 2         12   Yes  Yes
# 3         14   Yes  Yes
# 4         13   Yes   No

# %%
data['shelveloc']=data['shelveloc'].map({'Bad':0,'Medium':1,'Good':2})
data.head()
# Out:
#     sale  compprice  Income  advertising  Population  price  shelveloc  Age  \
# 0   9.50        138      73           11         276    120          0   42
# 1  11.22        111      48           16         260     83          2   65
# 2  10.06        113      35           10         269     80          1   59
# 3   7.40        117     100            4         466     97          1   55
# 4   4.15        141      64            3         340    128          0   38
#
#    education Urban   US
# 0         17   Yes  Yes
# 1         10   Yes  Yes
# 2         12   Yes  Yes
# 3         14   Yes  Yes
# 4         13   Yes   No

# %%
pd.cut(data['price'],3)
# Out:
# 0      (79.667, 135.333]
# 1      (79.667, 135.333]
# 2      (79.667, 135.333]
# 3      (79.667, 135.333]
# 4      (79.667, 135.333]
#              ...
# 395    (79.667, 135.333]
# 396    (79.667, 135.333]
# 397     (135.333, 191.0]
# 398    (79.667, 135.333]
# 399    (79.667, 135.333]
# Name: price, Length: 400, dtype: category
# Categories (3, interval[float64, right]): [(23.833, 79.667] < (79.667, 135.333] < (135.333, 191.0]]

# %%
data.groupby('price', as_index = False)['price'].agg(['min', 'max'])#
# Out:
#        min  max
# price
# 24      24   24
# 49      49   49
# 53      53   53
# 54      54   54
# 55      55   55
# ...    ...  ...
# 166    166  166
# 171    171  171
# 173    173  173
# 185    185  185
# 191    191  191
#
# [101 rows x 2 columns]

# %%
data['price_a']=pd.cut(data['price'],3,labels=['a','b','c'])
data.head(20)
# Out:
#      sale  compprice  Income  advertising  Population  price  shelveloc  Age  \
# 0    9.50        138      73           11         276    120          0   42
# 1   11.22        111      48           16         260     83          2   65
# 2   10.06        113      35           10         269     80          1   59
# 3    7.40        117     100            4         466     97          1   55
# 4    4.15        141      64            3         340    128          0   38
# 5   10.81        124     113           13         501     72          0   78
# 6    6.63        115     105            0          45    108          1   71
# 7   11.85        136      81           15         425    120          2   67
# 8    6.54        132     110            0         108    124          1   76
# 9    4.69        132     113            0         131    124          1   76
# 10   9.01        121      78            9         150    100          0   26
# ...

# %%
data.head(20)
# Out:
#      sale  compprice  Income  advertising  Population price  shelveloc  Age  \
# 0    9.50        138      73           11         276     b          0   42
# 1   11.22        111      48           16         260     b          2   65
# 2   10.06        113      35           10         269     b          1   59
# 3    7.40        117     100            4         466     b          1   55
# 4    4.15        141      64            3         340     b          0   38
# 5   10.81        124     113           13         501     a          0   78
# 6    6.63        115     105            0          45     b          1   71
# 7   11.85        136      81           15         425     b          2   67
# 8    6.54        132     110            0         108     b          1   76
# 9    4.69        132     113            0         131     b          1   76
# 10   9.01        121      78            9         150     b          0   26
# ...

# %%
data.groupby('price_a', as_index = False)['price'].agg(['min', 'max'])#
# Out:
#          min  max
# price_a
# a         24   79
# b         80  135
# c        136  191

# %%
# 등급 구하기
bin = [0, 24, 79, np.inf]
data['price_b'] = pd.cut(data['price'], bins=bin, labels=['a', 'b', 'c'])

data.head()
# Out:
#     sale  compprice  Income  advertising  Population  price  shelveloc  Age  \
# 0   9.50        138      73           11         276    120          0   42
# 1  11.22        111      48           16         260     83          2   65
# 2  10.06        113      35           10         269     80          1   59
# 3   7.40        117     100            4         466     97          1   55
# 4   4.15        141      64            3         340    128          0   38
#
#    education Urban   US price_a price_b
# 0         17   Yes  Yes       b       c
# 1         10   Yes  Yes       b       c
# 2         12   Yes  Yes       b       c
# 3         14   Yes  Yes       b       c
# 4         13   Yes   No       b       c

# %%
# 범위 확인
data.groupby('price_b', as_index = False)['price'].agg(['min', 'max'])
# Out:
#          min  max
# price_b
# a         24   24
# b         49   79
# c         80  191
